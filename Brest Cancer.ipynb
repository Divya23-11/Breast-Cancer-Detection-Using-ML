# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('breast-cancer.csv')

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
for column in df.columns:
    print("Unique Column",column)
    print(df[column].unique())
    print()
# Out:
# Unique Column id
# [   842302    842517  84300903  84348301  84358402    843786    844359
#   84458202    844981  84501001    845636  84610002    846226    846381
#   84667401  84799002    848406  84862001    849014   8510426   8510653
#    8510824   8511133    851509    852552    852631    852763    852781
#     852973    853201    853401    853612  85382601    854002    854039
#     854253    854268    854941    855133    855138    855167    855563
#     855625    856106  85638502    857010  85713702     85715    857155
#     857156    857343    857373    857374    857392    857438  85759902
#     857637    857793    857810    858477    858970    858981    858986
#     859196  85922302    859283    859464    859465    859471    859487
#     859575    859711    859717    859983   8610175   8610404   8610629
#    8610637   8610862   8610908    861103   8611161   8611555   8611792
#    8612080   8612399  86135501  86135502    861597    861598    861648
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df['radius_mean'].plot(kind='hist', bins=20, color='purple', edgecolor='black')
plt.title('Histogram of Radius Mean')
plt.xlabel('Radius Mean')
plt.tight_layout()
plt.show()

# %% [raw]
# Graph Type: Histogram
# This shows the distribution of the radius_mean values. Most tumor radii fall between 10 and 20, with a peak around 14.

# %%
plt.figure(figsize=(16, 24))
plt.subplot(3, 2, 1)
sns.countplot(data=df, x='diagnosis', palette='Set2')
plt.title('Diagnosis Count')
# Out:
# Text(0.5, 1.0, 'Diagnosis Count')

# %% [raw]
# Graph Type: Bar Plot (Count Plot)
# Benign tumors (B) are more common than malignant (M) in this dataset. This indicates a class imbalance.

# %%
plt.subplot(3, 2, 2)
sns.histplot(data=df, x='radius_mean', hue='diagnosis', kde=True, palette='husl')
plt.title('Radius Mean Distribution by Diagnosis')
# Out:
# Text(0.5, 1.0, 'Radius Mean Distribution by Diagnosis')

# %% [raw]
# Graph Type: Histogram with KDE and Hue
# Malignant tumors tend to have higher radius_mean values than benign ones. The distributions are visibly separated.

# %%
plt.subplot(3, 2, 3)
sns.boxplot(data=df, x='diagnosis', y='texture_mean', palette='coolwarm')
plt.title('Texture Mean by Diagnosis')
# Out:
# Text(0.5, 1.0, 'Texture Mean by Diagnosis')

# %% [raw]
# Graph Type: Box Plot
# Malignant tumors generally have higher texture_mean values. There is also greater variability in malignant cases.

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

# %%
label_encoder = LabelEncoder()

# %%
df['diagnosis_encoded'] = label_encoder.fit_transform(df['diagnosis'])

# %%
standard_scaler = StandardScaler()

# %%
df_standard_scaled = df.copy()

# %%
df_standard_scaled.iloc[:, 2:-1] = standard_scaler.fit_transform(df_standard_scaled.iloc[:, 2:-1])

# %%
minmax_scaler = MinMaxScaler()

# %%
df_minmax_scaled = df.copy()

# %%
df_minmax_scaled.iloc[:, 2:-1] = minmax_scaler.fit_transform(df_minmax_scaled.iloc[:, 2:-1])

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
onehot_encoder = OneHotEncoder(sparse=False, drop='first')

# %%
diagnosis_onehot = onehot_encoder.fit_transform(df[['diagnosis']])

# %%
diagnosis_onehot_df = pd.DataFrame(diagnosis_onehot, columns=['diagnosis_M'])

# %%
df_onehot_encoded = pd.concat([df.drop(columns='diagnosis'), diagnosis_onehot_df], axis=1)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df_standard_scaled.iloc[:, 2:-1].corr(), cmap='coolwarm', annot=False)
plt.title('Correlation Heatmap (Standard Scaled Features)')
plt.tight_layout()
plt.show()

# %% [raw]
# This heatmap shows pairwise correlations among standardized features using color intensity.
# Strong correlations are visible between radius_mean, area_mean, and perimeter_mean.

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df_minmax_scaled, x='diagnosis', y='radius_mean')
plt.title("Boxplot of Radius Mean by Diagnosis (MinMax Scaled)")
plt.tight_layout()
plt.show()

# %% [raw]
# This boxplot compares radius_mean distribution between benign and malignant tumors.
# Malignant tumors generally have a higher radius_mean than benign ones.

# %%
selected_features = ['radius_mean', 'texture_mean', 'area_mean', 'diagnosis']
sns.pairplot(df[selected_features], hue='diagnosis', palette='husl')
plt.suptitle("Pairplot of Selected Features", y=1.02)
plt.show()

# %% [raw]
# The pairplot reveals clusters and relationships between key features across diagnosis types.
# Malignant cases form distinct clusters with higher radius_mean and area_mean.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='diagnosis_encoded', data=df)
plt.title("Count of Diagnosis (Encoded)")
plt.xlabel("Diagnosis Encoded (0=B, 1=M)")
plt.tight_layout()
plt.show()

# %% [raw]
# This countplot shows the number of benign (0) and malignant (1) samples after label encoding.
# Benign cases are slightly more than malignant cases in the dataset.

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(data=df_minmax_scaled, x='diagnosis', y='texture_mean')
plt.title('Violin Plot of Texture Mean by Diagnosis (MinMax Scaled)')
plt.tight_layout()
plt.show()

# %% [raw]
# The violin plot displays the full distribution of texture_mean per diagnosis category.
# Malignant tumors show a wider spread and higher median in texture_mean values.

# %%
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

# %%
X = df.drop("diagnosis", axis=1)
y = df["diagnosis"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)
print("\nKNN Classification Report:\n", classification_report(y_test, y_pred_knn))
# Out:
# KNN Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       108
#            1       1.00      1.00      1.00        63
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171

# %% [markdown]
# # Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred_gnb = gnb.predict(X_test)
print("\nGaussian NB Classification Report:\n", classification_report(y_test, y_pred_gnb))
# Out:
# Gaussian NB Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       108
#            1       1.00      1.00      1.00        63
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logr = LogisticRegression(max_iter=1000)
logr.fit(X_train, y_train)
y_pred_logr = logr.predict(X_test)
print("\nLogistic Regression Classification Report:\n", classification_report(y_test, y_pred_logr))
# Out:
# Logistic Regression Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       108
#            1       1.00      1.00      1.00        63
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)
print("\nSVM Classification Report:\n", classification_report(y_test, y_pred_svm))
# Out:
# SVM Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       108
#            1       0.98      1.00      0.99        63
#
#     accuracy                           0.99       171
#    macro avg       0.99      1.00      0.99       171
# weighted avg       0.99      0.99      0.99       171

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
print("\nDecision Tree Classification Report:\n", classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       108
#            1       1.00      1.00      1.00        63
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print("\nRandom Forest Classification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       108
#            1       1.00      1.00      1.00        63
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171

# %% [markdown]
# # Ada Boost

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier()
ada.fit(X_train, y_train)
y_pred_ada = ada.predict(X_test)
print("\nAdaBoost Classification Report:\n", classification_report(y_test, y_pred_ada))
# Out:
# AdaBoost Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       108
#            1       1.00      1.00      1.00        63
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)
y_pred_gb = gb.predict(X_test)
print("\nGradient Boosting Classification Report:\n", classification_report(y_test, y_pred_gb))
# Out:
# Gradient Boosting Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       108
#            1       1.00      1.00      1.00        63
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171

# %% [markdown]
# # XG BOOST

# %%
from xgboost import XGBClassifier
xb =XGBClassifier()
xb.fit(X_train, y_train)
y_pred_gb = xb.predict(X_test)
print("\nGradient Boosting Classification Report:\n", classification_report(y_test, y_pred_gb))
# Out:
# Gradient Boosting Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       108
#            1       1.00      1.00      1.00        63
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171

# %% [markdown]
# # observation

# %%
models = ['KNN', 'GNB', 'LR', 'SVM', 'DT', 'RF', 'AB', 'XG', 'GradientBoosting']
accuracies = [1,1,1,0.99,1,1,1,1,1]
plt.figure(figsize=(10, 6))
plt.plot(models, accuracies, marker='o', linestyle='-', color='b')
plt.title('Model Accuracies')
plt.xlabel('Models')
plt.ylabel('Accuracy (%)')
plt.grid(True)
plt.show()

# %% [raw]
# The plot shows that most models including KNN, GNB, LR, DT, RF, AB, XG, and Gradient Boosting achieved perfect accuracy of 1.0, while the Support Vector Machine (SVM) model performed slightly lower with an accuracy of 0.99. This indicates that all models are highly effective on the given dataset, with minimal difference in performance among them.
